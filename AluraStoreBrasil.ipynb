# %% [markdown]
# <a href="https://colab.research.google.com/github/rayssasnt/analise-de-dados-com-pandas-e-matplotlib/blob/main/AluraStoreBrasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

# %% [markdown]
# #1. Análise do faturamento

# %% [markdown]
# ## loja 1

# %%
loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %%
faturamento_l1 = loja['Preço'].sum().round(2)
faturamento_l1
print(f"Faturamenro da loja 1 : R${faturamento_l1}")
# Out:
# Faturamenro da loja 1 : R$1534509.12

# %% [markdown]
# ## loja 2

# %%
loja2.head()
# Out:
#                  Produto   Categoria do Produto    Preço      Frete  \
# 0  Cadeira de escritório                 moveis   378.20  20.421138
# 1               Pandeiro  instrumentos musicais   102.37   3.035334
# 2              Cama king                 moveis   591.13  31.759020
# 3              Cama king                 moveis  1208.24  61.919584
# 4  Cadeira de escritório                 moveis   530.41  25.827176
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     04/08/2021    Thiago Silva              MG                    1
# 1     26/11/2020   Bianca Santos              RJ                    3
# 2     22/10/2021    Thiago Silva              SC                    5
# 3     04/05/2022   Larissa Alves              RS                    5
# 4     26/02/2022  Lucas Oliveira              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0            boleto                       1 -18.10 -44.38
# ...

# %%
faturamento_l2 = loja2['Preço'].sum().round(2)

print(f"Faturamenro da loja 2 : R${faturamento_l2}")
# Out:
# Faturamenro da loja 2 : R$1488459.06

# %% [markdown]
# ## loja 3

# %%
loja3.head()
# Out:
#               Produto   Categoria do Produto    Preço      Frete  \
# 0  Secadora de roupas       eletrodomesticos  1713.50  88.823159
# 1              Cômoda                 moveis   386.81  18.180908
# 2              Violão  instrumentos musicais   404.62  23.197592
# 3       Bola de vôlei        esporte e lazer    78.40   4.463341
# 4       Guarda roupas                 moveis   694.76  34.578319
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     17/12/2021  Camila Ribeiro              CE                    4
# 1     10/02/2021   Larissa Alves              RS                    3
# 2     22/01/2023  Lucas Oliveira              SP                    5
# 3     22/03/2022     Pedro Gomes              BA                    4
# 4     12/01/2022   Bianca Santos              SP                    1
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       4  -5.20 -39.53
# ...

# %%
faturamento_l3 = loja3['Preço'].sum().round(2)

print(f"Faturamenro da loja 3 : R${faturamento_l3}")
# Out:
# Faturamenro da loja 3 : R$1464025.03

# %% [markdown]
# ## loja 4

# %%
loja4.head()
# Out:
#                Produto Categoria do Produto    Preço      Frete  \
# 0          Lava louças     eletrodomesticos  1446.46  74.604083
# 1             Cama box               moveis   631.70  33.919251
# 2     Bola de basquete      esporte e lazer    31.54   0.000000
# 3  Modelagem preditiva               livros    76.93   1.680730
# 4       Fone de ouvido          eletronicos   185.14   7.442587
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     11/11/2022    Rafael Costa              SP                    4
# 1     03/01/2020    Thiago Silva              GO                    5
# 2     25/12/2022   Larissa Alves              MG                    5
# 3     23/11/2021  Lucas Oliveira              MG                    3
# 4     25/04/2022   Bianca Santos              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       3 -22.19 -48.79
# ...

# %%
faturamento_l4 = loja4['Preço'].sum().round(2)

print(f"Faturamenro da loja 4 : R${faturamento_l4}")
# Out:
# Faturamenro da loja 4 : R$1384497.58

# %%
dados = {'Loja' : ['LOJA 1',
                'LOJA 2' ,
                'LOJA 3',
                'LOJA 4'] ,
      'Faturamento' : [faturamento_l1,
                        faturamento_l2,
                        faturamento_l3,
                        faturamento_l4]}

df_faturamento = pd.DataFrame(dados)
faturamento = df_faturamento.sort_values(by='Faturamento' , ascending=False)
faturamento
# Out:
#      Loja  Faturamento
# 0  LOJA 1   1534509.12
# 1  LOJA 2   1488459.06
# 2  LOJA 3   1464025.03
# 3  LOJA 4   1384497.58

# %%
x = faturamento['Loja']
y = faturamento['Faturamento']

fig, ax = plt.subplots()

ax.bar(x, y)
ax.plot(x, y, marker='o' , color ='r')

ax.set_title('Faturamento por Loja')
ax.set_xlabel('Loja')
ax.set_ylabel('Faturamento em Milhões')

plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %% [markdown]
# ## loja 1

# %%
vendas_loja1 = loja.groupby('Categoria do Produto')[['Produto']].count().sort_values(by='Produto' , ascending=False)

vendas_loja1.rename(columns={'Produto': 'Quant. Vendas'}, inplace=True)

vendas_loja1
# Out:
#                        Quant. Vendas
# Categoria do Produto
# moveis                           465
# eletronicos                      448
# brinquedos                       324
# eletrodomesticos                 312
# esporte e lazer                  284
# instrumentos musicais            182
# livros                           173
# utilidades domesticas            171

# %% [markdown]
# ## loja 2

# %%
vendas_loja2 = loja2.groupby('Categoria do Produto')[['Produto']].count().sort_values(by='Produto' , ascending=False)

vendas_loja2.rename(columns={'Produto': 'Quant. Vendas'}, inplace=True)

vendas_loja2
# Out:
#                        Quant. Vendas
# Categoria do Produto
# moveis                           442
# eletronicos                      422
# brinquedos                       313
# eletrodomesticos                 305
# esporte e lazer                  275
# instrumentos musicais            224
# livros                           197
# utilidades domesticas            181

# %% [markdown]
# ## loja 3

# %%
vendas_loja3 = loja3.groupby('Categoria do Produto')[['Produto']].count().sort_values(by='Produto' , ascending=False)

vendas_loja3.rename(columns={'Produto': 'Quant. Vendas'}, inplace=True)

vendas_loja3
# Out:
#                        Quant. Vendas
# Categoria do Produto
# moveis                           499
# eletronicos                      451
# brinquedos                       315
# eletrodomesticos                 278
# esporte e lazer                  277
# livros                           185
# instrumentos musicais            177
# utilidades domesticas            177

# %% [markdown]
# ## Loja 4

# %%
vendas_loja4 = loja4.groupby('Categoria do Produto')[['Produto']].count().sort_values(by='Produto' , ascending=False)

vendas_loja4.rename(columns={'Produto': 'Quant. Vendas'}, inplace=True)

vendas_loja4
# Out:
#                        Quant. Vendas
# Categoria do Produto
# moveis                           480
# eletronicos                      451
# brinquedos                       338
# esporte e lazer                  277
# eletrodomesticos                 254
# utilidades domesticas            201
# livros                           187
# instrumentos musicais            170

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %% [markdown]
# ## loja 1

# %%
avaliacao1 = loja['Avaliação da compra'].mean().round(2)

print(f"A média de avaliação da loja 1 é : {avaliacao1} ")
# Out:
# A média de avaliação da loja 1 é : 3.98

# %% [markdown]
# ## loja 2

# %%
avaliacao2 = loja2['Avaliação da compra'].mean().round(2)

print(f"A média de avaliação da loja 2 é : {avaliacao2} ")
# Out:
# A média de avaliação da loja 2 é : 4.04

# %% [markdown]
# ## loja 3

# %%
avaliacao3 = loja3['Avaliação da compra'].mean().round(2)

print(f"A média de avaliação da loja 1 é : {avaliacao3} ")
# Out:
# A média de avaliação da loja 1 é : 4.05

# %% [markdown]
# ## loja 4

# %%
avaliacao4 = loja4['Avaliação da compra'].mean().round(2)

print(f"A média de avaliação da loja 1 é : {avaliacao4} ")
# Out:
# A média de avaliação da loja 1 é : 4.0

# %%
dados = {'Loja' : ['LOJA 1',
                'LOJA 2' ,
                'LOJA 3',
                'LOJA 4'] ,
      'Média de Avaliação' : [avaliacao1,
                        avaliacao2,
                        avaliacao3,
                        avaliacao4]}

df = pd.DataFrame(dados)
df
# Out:
#      Loja  Média de Avaliação
# 0  LOJA 1                3.98
# 1  LOJA 2                4.04
# 2  LOJA 3                4.05
# 3  LOJA 4                4.00

# %%
# função para mostrar a media

def format(y, x):
    absolute = (y/100.*x.sum())
    return f"{absolute:.2f}"


explode = (0.1,0,0.1,0)

labels = df['Loja']
sizes = df['Média de Avaliação']

fig , ax = plt.subplots()



ax.pie(sizes , explode = explode , labels = labels,
       shadow=True,
       startangle=90,
       colors= ['r','orange','g','orange'],
       autopct=lambda pct: format(pct, sizes)
       )

ax.set(title='Média de Avaliação de cada loja')
# Out:
# [Text(0.5, 1.0, 'Média de Avaliação de cada loja')]

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %% [markdown]
# ## Loja 1

# %%
# TOP 10 MAIS VENDIDOS
loja1_max = loja.groupby("Produto")[['Data da Compra']].count().sort_values(by='Data da Compra' , ascending=False).head(10)

loja1_max.rename(columns={'Data da Compra': 'Quantidade'}, inplace=True)

loja1_max
# Out:
#                     Quantidade
# Produto
# TV Led UHD 4K               60
# Micro-ondas                 60
# Guarda roupas               60
# Secadora de roupas          58
# Blocos de montar            56
# Cômoda                      56
# Bola de basquete            55
# Bicicleta                   54
# Copo térmico                54
# Geladeira                   54

# %%
loja1_max.plot(kind='barh', figsize=(14,10), color='y', xlabel='QUANT. DE VENDAS' ,ylabel='PRODUTOS', title='TOP 10 MAIS VENDIDOS');

# %%
# TOP 10 MENOS VENDIDOS
loja1_min = loja.groupby("Produto")[['Data da Compra']].count().sort_values(by='Data da Compra' , ascending=True).head(10)

loja1_min.rename(columns={'Data da Compra': 'Quantidade'}, inplace=True)

loja1_min
# Out:
#                              Quantidade
# Produto
# Celular ABXY                         33
# Headset                              33
# Panela de pressão                    35
# Pandeiro                             36
# Ciência de dados com python          39
# Mochila                              39
# Corda de pular                       40
# Assistente virtual                   40
# Mesa de jantar                       40
# Boneca bebê                          40

# %%
loja1_min.plot(kind='barh', figsize=(14,10), color='y', xlabel='QUANT. DE VENDAS' ,ylabel='PRODUTOS', title='TOP 10 MENOS VENDIDOS DA LOJA 1');

# %% [markdown]
# ## Loja 2

# %%
# TOP 10 MAIS VENDAS
loja2_max = loja2.groupby("Produto")[['Data da Compra']].count().sort_values(by='Data da Compra' , ascending=False).head(10)

loja2_max.rename(columns={'Data da Compra': 'Quantidade'}, inplace=True)

loja2_max
# Out:
#                           Quantidade
# Produto
# Iniciando em programação          65
# Micro-ondas                       62
# Bateria                           61
# Violão                            58
# Pandeiro                          58
# Secadora de roupas                57
# Celular Plus X42                  55
# Guarda roupas                     54
# Blocos de montar                  54
# Jogo de panelas                   52

# %% [markdown]
# MAIS VENDAS

# %%
loja2_max.plot(kind='bar', figsize=(14,10), color='y', xlabel='PRODUTOS' ,ylabel='QUANT. DE VENDAS', title='TOP 10 MAIS VENDIDOS DA LOJA 2');

# %% [markdown]
# MENOS VENDAS

# %%
# TOP 10 MENOS VENDAS
loja2_min = loja2.groupby("Produto")[['Data da Compra']].count().sort_values(by='Data da Compra' , ascending=True).head(10)

loja2_min .rename(columns={'Data da Compra': 'Quantidade'}, inplace=True)

loja2_min
# Out:
#                     Quantidade
# Produto
# Jogo de tabuleiro           32
# Impressora                  34
# Mesa de jantar              34
# Poltrona                    35
# Fone de ouvido              37
# Assistente virtual          38
# Faqueiro                    39
# Smart TV                    40
# Celular ABXY                41
# Fogão                       42

# %%
loja2_min .plot(kind='bar', figsize=(14,10), color='y', xlabel='PRODUTOS' ,ylabel='QUANT. DE VENDAS ', title='TOP 10 MENOS VENDIDOS DA LOJA 2');

# %% [markdown]
# ## Loja 3

# %%
# TOP 10 MAIS VENDAS
loja3_max = loja3.groupby("Produto")[['Data da Compra']].count().sort_values(by='Data da Compra' , ascending=False).head(10)

loja3_max.rename(columns={'Data da Compra': 'Quantidade'}, inplace=True)

loja3_max
# Out:
#                      Quantidade
# Produto
# Kit banquetas                57
# Mesa de jantar               56
# Cama king                    56
# Cômoda                       55
# Jogo de panelas              55
# Smart TV                     54
# Fogão                        53
# Modelagem preditiva          53
# Corda de pular               53
# Bicicleta                    52

# %% [markdown]
# MAIS VENDAS

# %%
loja3_max.plot(kind='barh', figsize=(14,10), color='y', xlabel='QUANT. DE VENDAS' ,ylabel='PRODUTOS', title='TOP 10 MAIS VENDIDOS DA LOJA 3');

# %% [markdown]
#  MENOS VENDAS

# %%
# TOP 10 MENOS VENDAS
loja3_min = loja3.groupby("Produto")[['Data da Compra']].count().sort_values(by='Data da Compra' , ascending=True).head(10)

loja3_min.rename(columns={'Data da Compra': 'Quantidade'}, inplace=True)

loja3_min
# Out:
#                     Quantidade
# Produto
# Blocos de montar            35
# Jogo de copos               36
# Micro-ondas                 36
# Mochila                     36
# Guitarra                    38
# Copo térmico                38
# Headset                     39
# Faqueiro                    39
# Boneca bebê                 39
# Assistente virtual          39

# %%
loja3_min.plot(kind='barh', figsize=(14,10), color='y', xlabel='QUANT. DE VENDAS' ,ylabel='PRODUTOS', title='TOP 10 MENOS VENDIDOS DA LOJA 3');

# %% [markdown]
# ## Loja 4

# %%
loja4_max = loja4.groupby("Produto")[['Data da Compra']].count().sort_values(by='Data da Compra' , ascending=False).head(10)

loja4_max.rename(columns={'Data da Compra': 'Quantidade'}, inplace=True)

loja4_max
# Out:
#                           Quantidade
# Produto
# Cama box                          62
# Faqueiro                          59
# Cama king                         56
# Dashboards com Power BI           56
# Cômoda                            55
# Mesa de jantar                    55
# Carrinho controle remoto          55
# Blocos de montar                  54
# Smart TV                          54
# Pandeiro                          52

# %% [markdown]
# MAIS VENDAS

# %%
loja4_max.plot(kind='barh', figsize=(14,10), color='y', xlabel='QUANT. DE VENDAS' ,ylabel='PRODUTOS', title='TOP 10 MAIS VENDIDOS DA LOJA 4');

# %% [markdown]
# MENOS VENDAS

# %%
loja4_min = loja4.groupby("Produto")[['Data da Compra']].count().sort_values(by='Data da Compra' , ascending=True).head(10)

loja4_min.rename(columns={'Data da Compra': 'Quantidade'}, inplace=True)

loja4_min
# Out:
#                              Quantidade
# Produto
# Guitarra                             33
# Guarda roupas                        34
# Violão                               37
# Ciência de dados com python          38
# Lavadora de roupas                   38
# Geladeira                            38
# Celular ABXY                         39
# Xadrez de madeira                    39
# Smartwatch                           39
# Cadeira de escritório                40

# %%
loja4_min.plot(kind='barh', figsize=(14,10), color='y', xlabel='QUANT. DE VENDAS' ,ylabel='PRODUTOS', title='TOP 10 MENOS VENDIDOS DA LOJA 4');

# %% [markdown]
# # 5. Frete Médio por Loja

# %% [markdown]
# ## Loja 1

# %%
frete_1 = loja['Frete'].mean().round(2)

print(f"O Frete médio da loja 1 é : R${frete_1}")
# Out:
# O Frete médio da loja 1 é : R$34.69

# %% [markdown]
# ## Loja 2

# %%
frete_2 = loja2['Frete'].mean().round(2)

print(f"O Frete médio da loja 2 é : R${frete_2}")
# Out:
# O Frete médio da loja 2 é : R$33.62

# %% [markdown]
# ## Loja 3

# %%
frete_3 = loja3['Frete'].mean().round(2)

print(f"O Frete médio da loja 3 é : R${frete_3}")
# Out:
# O Frete médio da loja 3 é : R$33.07

# %% [markdown]
# ## Loja 4

# %%
frete_4 = loja4['Frete'].mean().round(2)

print(f"O Frete médio da loja 4 é : R${frete_4}")
# Out:
# O Frete médio da loja 4 é : R$31.28

# %%
dados = {'Loja' : ['LOJA 1',
                'LOJA 2' ,
                'LOJA 3',
                'LOJA 4'] ,
      'Frete Médio' : [frete_1,
                        frete_2,
                        frete_3,
                        frete_4]}

df_frete = pd.DataFrame(dados)
frete = df_frete.sort_values(by='Frete Médio' , ascending=False)

frete
# Out:
#      Loja  Frete Médio
# 0  LOJA 1        34.69
# 1  LOJA 2        33.62
# 2  LOJA 3        33.07
# 3  LOJA 4        31.28

# %% [markdown]
# # Relatório
#
# Essa análise tem como objetivo comparar o desempenho de quatro lojas, utilizando dados de vendas para apoiar a tomada de decisão estratégica sobre qual unidade deve ser vendida
#
# Foram considerados indicadores relevantes como **faturamento total, média de avaliação dos clientes e frete médio**

# %% [markdown]
# ## Introdução

# %%
def format(y, x):
    absolute = (y/100.*x.sum())
    return f"{absolute:.2f}"


explode = (0.1,0,0.1,0)

labels = df['Loja']
sizes = df['Média de Avaliação']

fig , ax = plt.subplots()



ax.pie(sizes , explode = explode , labels = labels,
       shadow=True,
       startangle=90,
       colors= ['r','orange','g','orange'],
       autopct=lambda pct: format(pct, sizes)
       )

ax.set(title='Média de Avaliação de cada loja')
# Out:
# [Text(0.5, 1.0, 'Média de Avaliação de cada loja')]

# %%
x = faturamento['Loja']
y = faturamento['Faturamento']

fig, ax = plt.subplots()

ax.bar(x, y)
ax.plot(x, y, marker='o' , color ='r')

ax.set_title('Faturamento por Loja')
ax.set_xlabel('Loja')
ax.set_ylabel('Faturamento em Milhões')

plt.show()

# %%
x = frete['Loja']
y = frete['Frete Médio']

fig, ax = plt.subplots()

ax.bar(x, y , color='y')
ax.plot(x, y, marker='o' , color ='r')

ax.set_title('Frete Médio por Loja')
ax.set_xlabel('Loja')
ax.set_ylabel('Frete Médio R$')

plt.show()

# %% [markdown]
# **Loja 1**
#  - Maior Faturamento
# - Baixa avaliação
# - Frete mais alto
#
# Apesar do alto frete , tem o maior faturamento. Sendo assim não deve ser vendida
#
#
# ---
#
# **Loja 2**
# - 2° Maior Faturamento
# - 2° Melhor Avaliação
# - 2° Maior Frete
#
# Loja com bom faturamento e avaliação , também não deve ser vendida
#
#
# ---
#
# **Loja 3**
# - 3° Faturamento
# - Melhor Avaliação
# - 3° Maior Frete
#
# Loja com melhor avaliação de clientes , frete relativamente baixo e bom faturamento. Não deve ser vendida
#
# ---
#
# **Loja 4**
#
# - Menor Faturamento
# - 3° Avaliação
# - Menor Frete
#
# **A loja 4 deve ser vendida, apesar de possuir o menor custo médio de frete e uma uma boa avaliação , seu faturamento é o mais baixo entre as quatro lojas, demonstrando menor retorno financeiro**

# %% [markdown]
# #  Extra

# %%
df = loja[['lat','lon']]
df
# Out:
#         lat    lon
# 0    -22.19 -48.79
# 1    -22.25 -42.66
# 2    -15.83 -47.86
# 3    -30.17 -53.50
# 4    -18.10 -44.38
# ...     ...    ...
# 2354 -22.25 -42.66
# 2355 -22.19 -48.79
# 2356 -24.89 -51.55
# 2357  -5.81 -36.59
# 2358 -30.17 -53.50
#
# [2359 rows x 2 columns]

# %%
! pip install folium

import os
import folium

# %%
from folium.plugins import HeatMap
import os

# m = folium.Map([48., 5.], tiles='OpenStreetMap', zoom_start=6)

m = folium.Map(location=(-14.2401,-53.1805), tiles="cartodb positron" , zoom_start=4)

HeatMap(df).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
